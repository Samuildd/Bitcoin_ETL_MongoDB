# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuildd/Bitcoin_ETL_MongoDB/blob/main/ETL_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Extract

# %%
# !pip install pandas pymongo
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: pymongo in /usr/local/lib/python3.11/dist-packages (4.13.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pymongo) (2.7.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np

# %%
bitcoin_df = pd.read_csv('/content/drive/MyDrive/ETL_Project/btcusd_1-min_data.csv')

# %%
bitcoin_df.head()
#Running first 5 rows
# Out:
#       Timestamp  Open  High   Low  Close  Volume
# 0  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 1  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 2  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 3  1.325412e+09  4.58  4.58  4.58   4.58     0.0
# 4  1.325412e+09  4.58  4.58  4.58   4.58     0.0

# %%
bitcoin_df.info()
#Displaying Number of Rows,Columns, Columns names, and Datatypes.
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7080207 entries, 0 to 7080206
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Timestamp  float64
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Volume     float64
# dtypes: float64(6)
# memory usage: 324.1 MB

# %% [markdown]
# #Transform

# %%
bitcoin_df['Timestamp'].nunique()
#Checking number of unique Timestamps. As displayed 708207 unique timestamps meaning that there are no duplicate dates.
# Out:
# 7080207

# %%
bitcoin_df.isnull().sum()
#Checking if there are any null values within the bitcoin dataset.
# Out:
# Timestamp    0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# dtype: int64

# %%
bitcoin_df.describe()
#Values in Open, High, Low, Close and Volume are in scientific notation and hard to identify normally.
# Out:
#           Timestamp          Open          High           Low         Close  \
# count  7.080207e+06  7.080207e+06  7.080207e+06  7.080207e+06  7.080207e+06
# mean   1.537820e+09  1.825609e+04  1.826316e+04  1.824880e+04  1.825609e+04
# std    1.226351e+08  2.543148e+04  2.543940e+04  2.542337e+04  2.543145e+04
# min    1.325412e+09  3.800000e+00  3.800000e+00  3.800000e+00  3.800000e+00
# 25%    1.431615e+09  4.289600e+02  4.291000e+02  4.286950e+02  4.289700e+02
# 50%    1.537818e+09  6.722610e+03  6.725960e+03  6.719000e+03  6.722750e+03
# 75%    1.644021e+09  2.809300e+04  2.810000e+04  2.808500e+04  2.809300e+04
# max    1.750294e+09  1.119930e+05  1.120000e+05  1.119670e+05  1.119750e+05
#
#              Volume
# count  7.080207e+06
# mean   5.257430e+00
# std    2.241517e+01
# min    0.000000e+00
# 25%    1.798000e-02
# 50%    4.574131e-01
# 75%    3.000000e+00
# max    5.853852e+03

# %%
pd.set_option('display.float_format', '{:.2f}'.format)
#Changing from scientific notation to displaying normally.

# %%
bitcoin_df.describe()
#Values are more easily identfiable.
# Out:
#           Timestamp       Open       High        Low      Close     Volume
# count    7080207.00 7080207.00 7080207.00 7080207.00 7080207.00 7080207.00
# mean  1537819587.99   18256.09   18263.16   18248.80   18256.09       5.26
# std    122635081.10   25431.48   25439.40   25423.37   25431.45      22.42
# min   1325412060.00       3.80       3.80       3.80       3.80       0.00
# 25%   1431615150.00     428.96     429.10     428.69     428.97       0.02
# 50%   1537818240.00    6722.61    6725.96    6719.00    6722.75       0.46
# 75%   1644021330.00   28093.00   28100.00   28085.00   28093.00       3.00
# max   1750294020.00  111993.00  112000.00  111967.00  111975.00    5853.85

# %%
#Timestamp must be converted to datetime values to be easily identifiable.
bitcoin_df['Timestamp'] = pd.to_datetime(bitcoin_df['Timestamp'], unit='s')
#Converting timestamp from seconds to correct dates time values

# %%
bitcoin_df = bitcoin_df.rename(columns ={'Timestamp': 'Date'} )
#Renaming timestamp column to correct name.

# %%
bitcoin_df['Year'] = bitcoin_df['Date'].dt.year
bitcoin_df['Month'] = bitcoin_df['Date'].dt.month
bitcoin_df['Day'] = bitcoin_df['Date'].dt.day
#Extracting Year,Month and Day from Date.

# %%
bitcoin_df.describe()
#Values Year, Month and Date are all valid. Day has a min and max of 1/31. Month has a min and max of 1/12. Year has a min and max of 2012/2025.
# Out:
#                                 Date       Open       High        Low  \
# count                        7080207 7080207.00 7080207.00 7080207.00
# mean   2018-09-24 20:06:27.988717312   18256.09   18263.16   18248.80
# min              2012-01-01 10:01:00       3.80       3.80       3.80
# 25%              2015-05-14 14:52:30     428.96     429.10     428.69
# 50%              2018-09-24 19:44:00    6722.61    6725.96    6719.00
# 75%              2022-02-05 00:35:30   28093.00   28100.00   28085.00
# max              2025-06-19 00:47:00  111993.00  112000.00  111967.00
# std                              NaN   25431.48   25439.40   25423.37
#
#            Close     Volume       Year      Month        Day
# count 7080207.00 7080207.00 7080207.00 7080207.00 7080207.00
# mean    18256.09       5.26    2018.24       6.41      15.71
# min         3.80       0.00    2012.00       1.00       1.00
# 25%       428.97       0.02    2015.00       3.00       8.00
# 50%      6722.75       0.46    2018.00       6.00      16.00
# 75%     28093.00       3.00    2022.00       9.00      23.00
# max    111975.00    5853.85    2025.00      12.00      31.00
# std     25431.45      22.42       3.89       3.45       8.80

# %%
bitcoin_df['minute_change'] = bitcoin_df['Close'] - bitcoin_df['Close'].shift(1)
#As each row represents a minute, I've added a column that represents the difference form each minute

# %%
bitcoin_df.head()
# Out:
#                  Date  Open  High  Low  Close  Volume  Year  Month  Day  \
# 0 2012-01-01 10:01:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 1 2012-01-01 10:02:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 2 2012-01-01 10:03:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 3 2012-01-01 10:04:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 4 2012-01-01 10:05:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
#
#    minute_change
# 0            NaN
# 1           0.00
# 2           0.00
# 3           0.00
# 4           0.00

# %%
print(bitcoin_df[bitcoin_df['Open']<0])
print(bitcoin_df[bitcoin_df['High']<0])
print(bitcoin_df[bitcoin_df['Low']<0])
print(bitcoin_df[bitcoin_df['Volume']<0])
#Running a check to if there any unusual values within the dataset.
# Out:
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Year, Month, Day, minute_change]
# Index: []
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Year, Month, Day, minute_change]
# Index: []
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Year, Month, Day, minute_change]
# Index: []
# Empty DataFrame
# Columns: [Date, Open, High, Low, Close, Volume, Year, Month, Day, minute_change]
# Index: []

# %%
bitcoin_df['Day_Of_Week'] = bitcoin_df['Date'].dt.dayofweek
#Extracting day of the week

# %%
bitcoin_df.head()
# Out:
#                  Date  Open  High  Low  Close  Volume  Year  Month  Day  \
# 0 2012-01-01 10:01:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 1 2012-01-01 10:02:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 2 2012-01-01 10:03:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 3 2012-01-01 10:04:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 4 2012-01-01 10:05:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
#
#    minute_change  Day_Of_Week
# 0            NaN            6
# 1           0.00            6
# 2           0.00            6
# 3           0.00            6
# 4           0.00            6

# %%
def change_date(x):
  if x == 0:
    return 'Monday'
  elif x == 1:
      return 'Tuesday'
  elif x == 2:
    return 'Wednesday'
  elif x == 3:
    return 'Thursday'
  elif x == 4:
    return "Friday"
  elif x == 5:
    return "Saturday"
  elif x == 6:
    return "Sunday"
#Defining function to transform from numerical day of week to string.

# %%
bitcoin_df["DayOfWeek"] = bitcoin_df['Day_Of_Week'].apply(change_date)
#Transforming numerical day of week to string day of week

# %%
bitcoin_df.head()
# Out:
#                  Date  Open  High  Low  Close  Volume  Year  Month  Day  \
# 0 2012-01-01 10:01:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 1 2012-01-01 10:02:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 2 2012-01-01 10:03:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 3 2012-01-01 10:04:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 4 2012-01-01 10:05:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
#
#    minute_change  Day_Of_Week DayOfWeek
# 0            NaN            6    Sunday
# 1           0.00            6    Sunday
# 2           0.00            6    Sunday
# 3           0.00            6    Sunday
# 4           0.00            6    Sunday

# %%
bitcoin_df.drop(['Day_Of_Week'], axis = 1)
#Dropping numerical day of week.
# Out:
#                        Date      Open      High       Low     Close  Volume  \
# 0       2012-01-01 10:01:00      4.58      4.58      4.58      4.58    0.00
# 1       2012-01-01 10:02:00      4.58      4.58      4.58      4.58    0.00
# 2       2012-01-01 10:03:00      4.58      4.58      4.58      4.58    0.00
# 3       2012-01-01 10:04:00      4.58      4.58      4.58      4.58    0.00
# 4       2012-01-01 10:05:00      4.58      4.58      4.58      4.58    0.00
# ...                     ...       ...       ...       ...       ...     ...
# 7080202 2025-06-19 00:43:00 105185.00 105217.00 105185.00 105217.00    0.01
# 7080203 2025-06-19 00:44:00 105217.00 105217.00 105174.00 105183.00    0.62
# 7080204 2025-06-19 00:45:00 105184.00 105187.00 105184.00 105187.00    0.13
# 7080205 2025-06-19 00:46:00 105193.00 105193.00 105151.00 105193.00    0.86
# 7080206 2025-06-19 00:47:00 105224.00 105254.00 105224.00 105224.00    1.06
#
#          Year  Month  Day  minute_change DayOfWeek
# 0        2012      1    1            NaN    Sunday
# 1        2012      1    1           0.00    Sunday
# 2        2012      1    1           0.00    Sunday
# 3        2012      1    1           0.00    Sunday
# 4        2012      1    1           0.00    Sunday
# ...       ...    ...  ...            ...       ...
# 7080202  2025      6   19          75.00  Thursday
# 7080203  2025      6   19         -34.00  Thursday
# 7080204  2025      6   19           4.00  Thursday
# 7080205  2025      6   19           6.00  Thursday
# 7080206  2025      6   19          31.00  Thursday
#
# [7080207 rows x 11 columns]

# %%
NZD_Conversion_rate = 1.67
#This is the current conversion rate from usd to nzd as of June 20th 2025, 2pm.

# %%
bitcoin_df['close_NZD_Price'] = bitcoin_df['Close'] * NZD_Conversion_rate
#Added the column of NZD bitcoin prices

# %% [markdown]
# #Load

# %%
sub_df = bitcoin_df.loc[:20000]
sub_df.head()
#Created a sub version of bitcoin_df as the original is too large for me to run on free tier.
# Out:
#                  Date  Open  High  Low  Close  Volume  Year  Month  Day  \
# 0 2012-01-01 10:01:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 1 2012-01-01 10:02:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 2 2012-01-01 10:03:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 3 2012-01-01 10:04:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
# 4 2012-01-01 10:05:00  4.58  4.58 4.58   4.58    0.00  2012      1    1
#
#    minute_change  Day_Of_Week DayOfWeek  close_NZD_Price
# 0            NaN            6    Sunday             7.65
# 1           0.00            6    Sunday             7.65
# 2           0.00            6    Sunday             7.65
# 3           0.00            6    Sunday             7.65
# 4           0.00            6    Sunday             7.65

# %%
#LOAD

from pymongo import MongoClient

# 1️.) Connect
client = MongoClient("mongodb+srv://Samuild:*PASSWORD*@samuild.u1q4l85.mongodb.net/?retryWrites=true&w=majority")

# 2️.) Choose database and collection
db = client['Bitcoin_History']
collection = db['BCH']


# 4️.) Convert DataFrame to list of dicts
data_dict = sub_df.to_dict("records")

# 5️.) Insert data!
collection.insert_many(data_dict)
# Out:
# InsertManyResult([ObjectId('6854cb7cd3d634ac8833589e'), ObjectId('6854cb7cd3d634ac8833589f'), ObjectId('6854cb7cd3d634ac883358a0'), ObjectId('6854cb7cd3d634ac883358a1'), ObjectId('6854cb7cd3d634ac883358a2'), ObjectId('6854cb7cd3d634ac883358a3'), ObjectId('6854cb7cd3d634ac883358a4'), ObjectId('6854cb7cd3d634ac883358a5'), ObjectId('6854cb7cd3d634ac883358a6'), ObjectId('6854cb7cd3d634ac883358a7'), ObjectId('6854cb7cd3d634ac883358a8'), ObjectId('6854cb7cd3d634ac883358a9'), ObjectId('6854cb7cd3d634ac883358aa'), ObjectId('6854cb7cd3d634ac883358ab'), ObjectId('6854cb7cd3d634ac883358ac'), ObjectId('6854cb7cd3d634ac883358ad'), ObjectId('6854cb7cd3d634ac883358ae'), ObjectId('6854cb7cd3d634ac883358af'), ObjectId('6854cb7cd3d634ac883358b0'), ObjectId('6854cb7cd3d634ac883358b1'), ObjectId('6854cb7cd3d634ac883358b2'), ObjectId('6854cb7cd3d634ac883358b3'), ObjectId('6854cb7cd3d634ac883358b4'), ObjectId('6854cb7cd3d634ac883358b5'), ObjectId('6854cb7cd3d634ac883358b6'), ObjectId('6854cb7cd3d634ac883358b7'), ObjectId('6854cb7cd3d634ac883358b8'), ObjectId('6854cb7cd3d634ac883358b9'), ObjectId('6854cb7cd3d634ac883358ba'), ObjectId('6854cb7cd3d634ac883358bb'), ObjectId('6854cb7cd3d634ac883358bc'), ObjectId('6854cb7cd3d634ac883358bd'), ObjectId('6854cb7cd3d634ac883358be'), ObjectId('6854cb7cd3d634ac883358bf'), ObjectId('6854cb7cd3d634ac883358c0'), ObjectId('6854cb7cd3d634ac883358c1'), ObjectId('6854cb7cd3d634ac883358c2'), ObjectId('6854cb7cd3d634ac883358c3'), ObjectId('6854cb7cd3d634ac883358c4'), ObjectId('6854cb7cd3d634ac883358c5'), ObjectId('6854cb7cd3d634ac883358c6'), ObjectId('6854cb7cd3d634ac883358c7'), ObjectId('6854cb7cd3d634ac883358c8'), ObjectId('6854cb7cd3d634ac883358c9'), ObjectId('6854cb7cd3d634ac883358ca'), ObjectId('6854cb7cd3d634ac883358cb'), ObjectId('6854cb7cd3d634ac883358cc'), ObjectId('6854cb7cd3d634ac883358cd'), ObjectId('6854cb7cd3d634ac883358ce'), ObjectId('6854cb7cd3d634ac883358cf'), ObjectId('6854cb7cd3d634ac883358d0'), ObjectId('6854cb7cd3d634ac883358d1'), ObjectId('6854cb7cd3d634ac883358d2'), ObjectId('6854cb7cd3d634ac883358d3'), ObjectId('6854cb7cd3d634ac883358d4'), ObjectId('6854cb7cd3d634ac883358d5'), ObjectId('6854cb7cd3d634ac883358d6'), ObjectId('6854cb7cd3d634ac883358d7'), ObjectId('6854cb7cd3d634ac883358d8'), ObjectId('6854cb7cd3d634ac883358d9'), ObjectId('6854cb7cd3d634ac883358da'), ObjectId('6854cb7cd3d634ac883358db'), ObjectId('6854cb7cd3d634ac883358dc'), ObjectId('6854cb7cd3d634ac883358dd'), ObjectId('6854cb7cd3d634ac883358de'), ObjectId('6854cb7cd3d634ac883358df'), ObjectId('6854cb7cd3d634ac883358e0'), ObjectId('6854cb7cd3d634ac883358e1'), ObjectId('6854cb7cd3d634ac883358e2'), ObjectId('6854cb7cd3d634ac883358e3'), ObjectId('6854cb7cd3d634ac883358e4'), ObjectId('6854cb7cd3d634ac883358e5'), ObjectId('6854cb7cd3d634ac883358e6'), ObjectId('6854cb7cd3d634ac883358e7'), ObjectId('6854cb7cd3d634ac883358e8'), ObjectId('6854cb7cd3d634ac883358e9'), ObjectId('6854cb7cd3d634ac883358ea'), ObjectId('6854cb7cd3d634ac883358eb'), ObjectId('6854cb7cd3d634ac883358ec'), ObjectId('6854cb7cd3d634ac883358ed'), ObjectId('6854cb7cd3d634ac883358ee'), ObjectId('6854cb7cd3d634ac883358ef'), ObjectId('6854cb7cd3d634ac883358f0'), ObjectId('6854cb7cd3d634ac883358f1'), ObjectId('6854cb7cd3d634ac883358f2'), ObjectId('6854cb7cd3d634ac883358f3'), ObjectId('6854cb7cd3d634ac883358f4'), ObjectId('6854cb7cd3d634ac883358f5'), ObjectId('6854cb7cd3d634ac883358f6'), ObjectId('6854cb7cd3d634ac883358f7'), ObjectId('6854cb7cd3d634ac883358f8'), ObjectId('6854cb7cd3d634ac883358f9'), ObjectId('6854cb7cd3d634ac883358fa'), ObjectId('6854cb7cd3d634ac883358fb'), ObjectId('6854cb7cd3d634ac883358fc'), ObjectId('6854cb7cd3d634ac883358fd'), ObjectId('6854cb7cd3d634ac883358fe'), ObjectId('6854cb7cd3d634ac883358ff'), ObjectId('6854cb7cd3d634ac88335900'), ObjectId('6854cb7cd3d634ac88335901'), ObjectId('6854cb7cd3d634ac88335902'), ObjectId('6854cb7cd3d634ac88335903'), ObjectId('6854cb7cd3d634ac88335904'), ObjectId('6854cb7cd3d634ac88335905'), ObjectId('6854cb7cd3d634ac8833 ...
